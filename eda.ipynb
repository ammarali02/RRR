# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import data_manipulation as data

# %matplotlib inline

# %%
data.random_sample("feature-data/", 'sample-data/', 0.05)

# %%
df = data.to_dataframe('sample-data')
df
# Out:
# /Users/adityaramesh/Desktop/CS/Projects/atlas-trash-classification/venv/lib/python3.11/site-packages/PIL/Image.py:1000: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#                                           Width  Height  Aspect Ratio  \
# Category            Name
# paper               paper 15.jpg           1300    1300      1.000000
#                     paper 679.jpg           512     384      1.333333
#                     paper 447.jpg           512     384      1.333333
#                     paper 323.jpg           626     417      1.501199
#                     paper 280.jpg           783    1024      0.764648
# ...                                         ...     ...           ...
# spray cans          spray_cans 433.jpg      500     500      1.000000
#                     spray_cans 3.jpg        550     550      1.000000
#                     spray_cans 181.jpg      600     600      1.000000
# other metal objects metal_objects 3.jpg     600     600      1.000000
#                     metal_objects 12.jpg    188     250      0.752000
#
#                                                 Mean  Standard Deviation
# Category            Name
# paper               paper 15.jpg          237.204493           16.044554
#                     paper 679.jpg         182.616514           26.669136
#                     paper 447.jpg         176.790987           32.261952
#                     paper 323.jpg         102.126688           41.005366
#                     paper 280.jpg         230.202643           24.132468
# ...                                              ...                 ...
# spray cans          spray_cans 433.jpg    228.945239           65.877928
#                     spray_cans 3.jpg      216.117927           57.952432
#                     spray_cans 181.jpg    228.824326           57.212734
# other metal objects metal_objects 3.jpg   164.331486           40.265727
#                     metal_objects 12.jpg  109.789050           48.320250
#
# [884 rows x 5 columns]

# %%
df_all = df.groupby('Category').mean()
df_all
# Out:
#                            Width       Height  Aspect Ratio        Mean  \
# Category
# beverage cans         749.460000   687.780000      1.184781  170.437412
# cardboard             816.716667   688.333333      1.273742  162.185398
# cigarette butt        512.000000   512.000000      1.000000  119.092115
# construction scrap    493.307692   399.538462      1.162366  116.553223
# electrical cables     817.852941   773.647059      1.222728  166.474443
# electronic chips      881.466667   706.200000      1.316367  131.826873
# glass                 754.841270   680.460317      1.177963  147.538856
# gloves                626.727273   527.136364      1.218980  190.912860
# laptops               912.440000   689.240000      1.378155  138.768576
# masks                 820.720000   567.480000      1.449277  116.704319
# medicines            1080.640000   707.040000      1.580713  150.354717
# metal containers      616.480000   540.040000      1.153325  193.333414
# news paper           1161.000000   920.500000      1.310458  145.163459
# other metal objects   394.000000   425.000000      0.876000  137.060268
# paper                 685.905660   525.849057      1.304969  174.530948
# paper cups            430.322581   422.903226      1.036334  200.624166
# plastic bags         1103.400000   874.840000      1.362534  158.407665
# plastic bottles      1547.607143  1565.750000      1.094452  125.928626
# plastic containers    961.206897   729.689655      1.175574  195.165685
# plastic cups          503.560000   518.760000      0.998258  206.254418
# small appliances      279.826087   272.934783      1.130176  198.940412
# smartphones          1366.384615  1001.000000      1.356770  153.511465
# spray cans            625.000000   539.080000      1.157366  180.670158
# syringe              1881.480000  1201.400000      1.550283  139.200589
# tetra pak             301.871795   353.769231      0.941697  147.626970
#
#                      Standard Deviation
# Category
# beverage cans                 61.653513
# cardboard                     54.246952
# cigarette butt                54.840700
# construction scrap            59.569933
# electrical cables             63.450765
# electronic chips              63.569617
# glass                         56.927755
# gloves                        56.731881
# laptops                       74.475340
# masks                         55.938025
# medicines                     57.351137
# metal containers              56.410115
# news paper                    62.921905
# other metal objects           44.292988
# paper                         40.836646
# paper cups                    50.596146
# plastic bags                  53.086655
# plastic bottles               56.670820
# plastic containers            40.085661
# plastic cups                  40.231658
# small appliances              58.162006
# smartphones                   65.398896
# spray cans                    59.191748
# syringe                       55.670417
# tetra pak                     62.344270

# %%
count_df = df.groupby('Category').size().reset_index(name='Count')

df_all = pd.merge(df_all, count_df, on = 'Category')
df_all
# Out:
#                Category        Width       Height  Aspect Ratio        Mean  \
# 0         beverage cans   749.460000   687.780000      1.184781  170.437412
# 1             cardboard   816.716667   688.333333      1.273742  162.185398
# 2        cigarette butt   512.000000   512.000000      1.000000  119.092115
# 3    construction scrap   493.307692   399.538462      1.162366  116.553223
# 4     electrical cables   817.852941   773.647059      1.222728  166.474443
# 5      electronic chips   881.466667   706.200000      1.316367  131.826873
# 6                 glass   754.841270   680.460317      1.177963  147.538856
# 7                gloves   626.727273   527.136364      1.218980  190.912860
# 8               laptops   912.440000   689.240000      1.378155  138.768576
# 9                 masks   820.720000   567.480000      1.449277  116.704319
# 10            medicines  1080.640000   707.040000      1.580713  150.354717
# 11     metal containers   616.480000   540.040000      1.153325  193.333414
# 12           news paper  1161.000000   920.500000      1.310458  145.163459
# 13  other metal objects   394.000000   425.000000      0.876000  137.060268
# 14                paper   685.905660   525.849057      1.304969  174.530948
# 15           paper cups   430.322581   422.903226      1.036334  200.624166
# 16         plastic bags  1103.400000   874.840000      1.362534  158.407665
# 17      plastic bottles  1547.607143  1565.750000      1.094452  125.928626
# 18   plastic containers   961.206897   729.689655      1.175574  195.165685
# 19         plastic cups   503.560000   518.760000      0.998258  206.254418
# 20     small appliances   279.826087   272.934783      1.130176  198.940412
# 21          smartphones  1366.384615  1001.000000      1.356770  153.511465
# 22           spray cans   625.000000   539.080000      1.157366  180.670158
# 23              syringe  1881.480000  1201.400000      1.550283  139.200589
# 24            tetra pak   301.871795   353.769231      0.941697  147.626970
#
#     Standard Deviation  Count
# 0            61.653513     50
# 1            54.246952    120
# 2            54.840700     25
# 3            59.569933     26
# 4            63.450765     34
# 5            63.569617     30
# 6            56.927755    126
# 7            56.731881     22
# 8            74.475340     25
# 9            55.938025     25
# 10           57.351137     25
# 11           56.410115     25
# 12           62.921905     10
# 13           44.292988      2
# 14           40.836646     53
# 15           50.596146     31
# 16           53.086655     25
# 17           56.670820     28
# 18           40.085661     29
# 19           40.231658     25
# 20           58.162006     46
# 21           65.398896     13
# 22           59.191748     25
# 23           55.670417     25
# 24           62.344270     39

# %%
plt.figure(figsize=(15,4))
plot = sns.barplot(data = df_all, x = 'Category', y = 'Count')
plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/37/sx6z_q_157dgwvn2l9s1k8g80000gn/T/ipykernel_8733/1149616306.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)

# %%
plt.figure(figsize=(15,4))
plot = sns.barplot(data = df_all, x = 'Category', y = 'Width')
plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/37/sx6z_q_157dgwvn2l9s1k8g80000gn/T/ipykernel_8733/2723030107.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)

# %%
plt.figure(figsize=(15,4))
plot = sns.barplot(data = df_all, x = 'Category', y = 'Height')
plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/37/sx6z_q_157dgwvn2l9s1k8g80000gn/T/ipykernel_8733/2590244522.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)

# %%
plt.figure(figsize=(15,4))
plot = sns.barplot(data = df_all, x = 'Category', y = 'Mean')
plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/37/sx6z_q_157dgwvn2l9s1k8g80000gn/T/ipykernel_8733/3878936276.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)

# %%
plt.figure(figsize=(15,4))
plot = sns.barplot(data = df_all, x = 'Category', y = 'Standard Deviation')
plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/37/sx6z_q_157dgwvn2l9s1k8g80000gn/T/ipykernel_8733/788807326.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)

# %%
data.random_sample("feature-data", 'sample-data-large/', 0.25)
df_large = data.to_dataframe('sample-data-large/')
df_large.reset_index(inplace=True)
# Out:
# /Users/adityaramesh/Desktop/CS/Projects/atlas-trash-classification/venv/lib/python3.11/site-packages/PIL/Image.py:1000: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
g = sns.relplot(data=df_large, x='Width', y='Height',col='Category', col_wrap=4, height=4, aspect=1.5, kind='scatter', legend = False)
for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(40)
        label.set_fontsize(7)

g.figure.suptitle('Aspect Ratio per Category', fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()
