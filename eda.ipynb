# %% [markdown]
# ###
# THIS IS CURRENTLY A WIP. JUST SHOWS OFF FUNCTIONALITY AS OF NOW (06/22/2024)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import data_manipulation as data

# %matplotlib inline

# %%
data.random_sample("feature-data/", 0.05)

# %%
df = data.to_dataframe('sample-data')

# %%
df
# Out:
#                                           Width  Height  Aspect Ratio  \
# Category            Name
# paper               paper 678.jpg           512     384      1.333333
#                     paper 730.jpg           512     384      1.333333
#                     paper 283.jpg          1024    1024      1.000000
#                     paper 492.jpg           512     384      1.333333
#                     paper 337.jpg           512     384      1.333333
# ...                                         ...     ...           ...
# spray cans          spray_cans 381.jpg      300     300      1.000000
#                     spray_cans 74.jpg       238     320      0.743750
#                     spray_cans 194.jpg      299     300      0.996667
# other metal objects metal_objects 18.jpg    408     612      0.666667
#                     metal_objects 1.jpg     600     600      1.000000
#
#                                                 Mean  Standard Deviation
# Category            Name
# paper               paper 678.jpg         169.436796           43.341937
#                     paper 730.jpg         185.176170           36.692180
#                     paper 283.jpg         248.704232            6.290401
#                     paper 492.jpg         155.824826           56.023605
#                     paper 337.jpg         148.746665           63.259384
# ...                                              ...                 ...
# spray cans          spray_cans 381.jpg    186.067848           73.494947
#                     spray_cans 74.jpg     154.770693           76.620280
#                     spray_cans 194.jpg    227.728729           33.200948
# other metal objects metal_objects 18.jpg   65.335090           49.032452
#                     metal_objects 1.jpg   151.215646           36.008257
#
# [884 rows x 5 columns]
