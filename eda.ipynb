# %% [markdown]
# ###
# THIS IS CURRENTLY A WIP. JUST SHOWS OFF FUNCTIONALITY AS OF NOW (06/22/2024)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import data_manipulation as data

# %matplotlib inline

# %%
data.random_sample("feature-data/", 0.05)

# %%
df = data.to_dataframe('sample-data')
df
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#                                           Width  Height  Aspect Ratio  \
# Category            Name
# paper               paper 485.jpg           512     384      1.333333
#                     paper 308.jpg           800     500      1.600000
#                     paper 452.jpg           512     384      1.333333
#                     paper 1058.jpg         1300    1014      1.282051
#                     paper 690.jpg           512     384      1.333333
# ...                                         ...     ...           ...
# spray cans          spray_cans 49.jpg       542     360      1.505556
#                     spray_cans 88.jpg       236     353      0.668555
#                     spray_cans 156.jpg      300     300      1.000000
# ...

# %%
df_all = df.groupby('Category').mean()
df_all
# Out:
#                            Width       Height  Aspect Ratio        Mean  \
# Category
# beverage cans         639.320000   571.840000      1.153750  157.497693
# cardboard             788.225000   648.566667      1.282536  148.835918
# cigarette butt        512.000000   512.000000      1.000000  127.110684
# construction scrap    692.269231   591.807692      1.274785  140.797448
# electrical cables     763.235294   584.676471      1.320655  178.441289
# electronic chips      952.233333   668.333333      1.528974  137.611858
# glass                 840.857143   760.817460      1.159647  143.912954
# gloves                662.136364   489.727273      1.320239  189.396340
# laptops               843.800000   598.760000      1.481648  134.012598
# masks                 954.560000   653.200000      1.477500  137.138119
# medicines             955.680000   653.520000      1.472459  158.793138
# metal containers      632.160000   630.040000      1.093451  198.987228
# ...

# %%
count_df = df.groupby('Category').size().reset_index(name='Count')

df_all = pd.merge(df_all, count_df, on = 'Category')
df_all
# Out:
#                Category        Width       Height  Aspect Ratio        Mean  \
# 0         beverage cans   639.320000   571.840000      1.153750  157.497693
# 1             cardboard   788.225000   648.566667      1.282536  148.835918
# 2        cigarette butt   512.000000   512.000000      1.000000  127.110684
# 3    construction scrap   692.269231   591.807692      1.274785  140.797448
# 4     electrical cables   763.235294   584.676471      1.320655  178.441289
# 5      electronic chips   952.233333   668.333333      1.528974  137.611858
# 6                 glass   840.857143   760.817460      1.159647  143.912954
# 7                gloves   662.136364   489.727273      1.320239  189.396340
# 8               laptops   843.800000   598.760000      1.481648  134.012598
# 9                 masks   954.560000   653.200000      1.477500  137.138119
# 10            medicines   955.680000   653.520000      1.472459  158.793138
# ...

# %%
plt.figure(figsize=(15,4))
plot = sns.barplot(data = df_all, x = 'Category', y = 'Count')
plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/37/sx6z_q_157dgwvn2l9s1k8g80000gn/T/ipykernel_91969/1149616306.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot.set_xticklabels(plot.get_xticklabels(), rotation = 40, fontsize=7)
